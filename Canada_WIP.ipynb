# %%
# import required packages and functions
from concerning_climate.historic_emissions import Historic_Emissions
import matplotlib.pyplot as plt

# %%
#Get data frame with Canada data for all sectors and years
Canada = Historic_Emissions("Instance of the class for looking at Canadian emissions")
# Out:
# Reading URL again

# %%
df_canada_2000 = Canada.hist_table(['Canada'], [2000], 'all')
df_canada_all = Canada.hist_table(['Canada'], 'all', 'all')

# %%
df_canada_2000
# Out:
#                                           2000
# ISO_NAME sector
# Canada   All sectors                  0.728217
#          Buildings                    0.094648
#          Non-combustion               0.212378
#          Other industrial combustion  0.135785
#          Power Industry               0.135444
#          Transport                    0.149962

# %%
df_canada_all
# Out:
#                                           1970      1971      1972      1973  \
# ISO_NAME sector
# Canada   All sectors                  0.454901  0.462351  0.481054  0.500287
#          Buildings                    0.098345  0.098660  0.105950  0.094654
#          Non-combustion               0.121721  0.121818  0.122855  0.124310
#          Other industrial combustion  0.108435  0.108319  0.112029  0.131188
#          Power Industry               0.044997  0.049322  0.050128  0.051873
#          Transport                    0.081403  0.084232  0.090092  0.098262
#
#                                           1974      1975      1976      1977  \
# ISO_NAME sector
# Canada   All sectors                  0.508719  0.498497  0.511243  0.525279
#          Buildings                    0.099653  0.094235  0.098518  0.096908
#          Non-combustion               0.123038  0.121000  0.121543  0.123111
#          Other industrial combustion  0.132970  0.124846  0.123300  0.129018
# ...

# %%
all_countries = Canada.countries_reminder()
sorted(all_countries)
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'Angola',
#  'Anguilla',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas (the)',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia (Plurinational State of)',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Brunei Darussalam',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cabo Verde',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Cayman Islands (the)',
#  'Central African Republic (the)',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros (the)',
#  'Congo (the Democratic Republic of the)',
#  'Congo (the)',
#  'Cook Islands (the)',
#  'Costa Rica',
#  "Cote d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Curacao',
#  'Cyprus',
#  'Czechia',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic (the)',
#  'EU28',
#  'Ecuador',
#  'Egypt',
# ...

# %%
countries = ['Canada', 'United States of America (the)', 'Australia', 'China']
years = list(range(1970,2017))
sector = 'All sectors'
df_area_countries = Canada.hist_table(countries, years, [sector]).xs(sector, level = 1)

# %%
df_area_countries
# Out:
#                                     1970      1971      1972      1973  \
# ISO_NAME
# Australia                       0.160029  0.161412  0.167306  0.176949
# Canada                          0.454901  0.462351  0.481054  0.500287
# China                           0.903068  0.906651  0.966841  1.007572
# United States of America (the)  4.585364  4.450199  4.698341  4.885719
#
#                                     1974      1975      1976      1977  \
# ISO_NAME
# Australia                       0.186085  0.192939  0.195732  0.208961
# Canada                          0.508719  0.498497  0.511243  0.525279
# China                           1.023706  1.167282  1.211173  1.358351
# United States of America (the)  4.721317  4.512356  4.806025  4.967237
#
#                                     1978      1979    ...          2007  \
# ISO_NAME                                              ...
# Australia                       0.205436  0.211211    ...      0.426723
# ...

# %%
df_area_countries.T.plot.area()
plt.show()

# %%
#plot pie chart of sector breakdown
Canada.plot_pie('Canada', 2016)

# %%
#would be fun to make an animation - how the pie chart changes overtime. Would be even cooler if the pie got bigger as the total did

# %%
# plot area chart of all the sectors and how they have changed over time. 
Canada.plot_area_sectors('Canada')

# %%
Canada.plot_area_sectors('Canada', 2000, 2005)

# %%
country = 'United Kingdom of Great Britain and Northern Ireland (the)'
Canada.plot_area_sectors(country)

# %%
Canada.plot_area_sectors('Canada', sectors_off = True)

# %%
#plot emissions per country over time
countries = ['Canada', 'United States of America (the)', 'Australia', 'China', 'United Kingdom of Great Britain and Northern Ireland (the)']
Canada.plot_area_countries(countries)

# %%
# plot per capita emissions per country(all sectors) over time

# %%
#plot per unit GDP emissions per country (all sectors) over time

# %%
#plot per unit GDP/capita per country (all sectors) over time

# %%
# plot RCP scenario for the area scaled so it is per capita

# %%
# plot the above graph with the canadian per capita emissions
